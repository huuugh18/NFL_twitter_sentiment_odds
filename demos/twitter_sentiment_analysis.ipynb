# %% [markdown]
# ## Twitter Sentiment Analysis
#
# [Article Link](https://medium.com/@nikitasilaparasetty/twitter-sentiment-analysis-for-data-science-using-python-in-2022-6d5e43f6fa6e)

# %%
import re 

import numpy as np

import tweepy 

from tweepy import OAuthHandler 

from textblob import TextBlob 

import matplotlib.pyplot as plt

import pandas as pd

from wordcloud import WordCloud

from better_profanity import profanity

# %%
# Set up keys and auth api keys

import constants

consumer_key = constants.TWITTER_PUBLIC_API_KEY
consumer_secret = constants.TWITTER_PRIVATE_API_KEY

access_token = constants.TWITTER_ACCESS_TOKEN
access_token_secret = constants.TWITTER_PRIVATE_ACCESS_TOKEN

bearer_token = constants.TWITTER_BEARER_TOKEN

# %%
# Access Twitter Data

client = tweepy.Client(consumer_key, consumer_secret, access_token, access_token_secret)
# auth.set_access_token(access_token, access_token_secret)

# api = tweepy.API(auth)

# client = tweepy.Client(constants.TWITTER_BEARER_TOKEN)

# %% [markdown]
# # Can't retrieve old tweets with current account type - need research access

# %%
# tweet_ids=[22662042404, 22662135903, 22662138503]

response = client.search_recent_tweets('#titans', max_results=10)
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# c:\Users\hugho\Documents\datascience\500RP\twitter_sentiment_analysis.ipynb Cell 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hugho/Documents/datascience/500RP/twitter_sentiment_analysis.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # tweet_ids=[22662042404, 22662135903, 22662138503]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hugho/Documents/datascience/500RP/twitter_sentiment_analysis.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> response = client.search_recent_tweets('#titans', max_results=10)
#
# File c:\Users\hugho\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\client.py:1248, in Client.search_recent_tweets(self, query, user_auth, **params)
#    1156 """search_recent_tweets( \
#    1157     query, *, end_time=None, expansions=None, max_results=None, \
#    1158     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1245 .. _Academic Research Project: https://developer.twitter.com/en/docs/projects
#    1246 """
#    1247 params["query"] = query
# -> 1248 return self._make_request(
#    1249     "GET", "/2/tweets/search/recent", params=params,
#    1250     endpoint_parameters=(
#    1251         "end_time", "expansions", "max_results", "media.fields",
#    1252         "next_token", "place.fields", "poll.fields", "query",
#    1253         "since_id", "sort_order", "start_time", "tweet.fields",
#    1254         "until_id", "user.fields"
#    1255     ), data_type=Tweet, user_auth=user_auth
#    1256 )
#
# File c:\Users\hugho\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\client.py:126, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     122 def _make_request(self, method, route, params={}, endpoint_parameters=None,
#     123                   json=None, data_type=None, user_auth=False):
#     124     request_params = self._process_params(params, endpoint_parameters)
# --> 126     response = self.request(method, route, params=request_params,
#     127                             json=json, user_auth=user_auth)
#     129     if self.return_type is requests.Response:
#     130         return response
#
# File c:\Users\hugho\AppData\Local\Programs\Python\Python310\lib\site-packages\tweepy\client.py:97, in BaseClient.request(self, method, route, params, json, user_auth)
#      95     raise BadRequest(response)
#      96 if response.status_code == 401:
# ---> 97     raise Unauthorized(response)
#      98 if response.status_code == 403:
#      99     raise Forbidden(response)
#
# Unauthorized: 401 Unauthorized
# Unauthorized

# %% [markdown]
# We will first input a query from the user. We will then generate a list of the latest tweets, their users, and their locations, based on that query.

# %%
# Input a query from the user

query = "#CFL"

# In this case, we will input the query as 'Elon Musk'

# Filter the query to remove retweets

filtered = query + "-filter:retweets"

# Generate the latest tweets on the given query 

tweets = tweepy.Cursor(api.search_tweets, q=filtered,lang="en").items(100)

# Create a list of the tweets, the users, and their location

list1 = [[tweet.text, tweet.user.screen_name, tweet.user.location] for tweet in tweets]

print(list1[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\hugho\Documents\datascience\500RP\twitter_sentiment_analysis.ipynb Cell 8 in <cell line: 13>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hugho/Documents/datascience/500RP/twitter_sentiment_analysis.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> filtered = query + "-filter:retweets"
#      <a href='vscode-notebook-cell:/c%3A/Users/hugho/Documents/datascience/500RP/twitter_sentiment_analysis.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a> # Generate the latest tweets on the given query
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hugho/Documents/datascience/500RP/twitter_sentiment_analysis.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a> tweets = tweepy.Cursor(api.search_tweets, q=filtered,lang="en").items(100)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugho/Documents/datascience/500RP/twitter_sentiment_analysis.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> # Create a list of the tweets, the users, and their location
#      <a href='vscode-notebook-cell:/c%3A/Users/hugho/Documents/datascience/500RP/twitter_sentiment_analysis.ipynb#X10sZmlsZQ%3D%3D?line=16'>17</a> list1 = [[tweet.text, tweet.user.screen_name, tweet.user.location] for tweet in tweets]
#
# NameError: name 'api' is not defined

# %%
# Convert the list into a dataframe

df = pd.DataFrame(data=list1, columns=['tweets','user', "location"])# Convert only the tweets into a list

tweet_list = df.tweets.to_list()

# %%
# Create a function to clean the tweets. Remove profanity, unnecessary characters, spaces, and stopwords.

def clean_tweet(tweet):
    if type(tweet) == float:
        return ""
    r = tweet.lower()
    r = profanity.censor(r)
    r = re.sub("'", "", r) # This is to avoid removing contractions in english
    r = re.sub("@[A-Za-z0-9_]+","", r)
    r = re.sub("#[A-Za-z0-9_]+","", r)
    r = re.sub(r'http\S+', '', r)
    r = re.sub('[()!?]', ' ', r)
    r = re.sub('\[.*?\]',' ', r)
    r = re.sub("[^a-z0-9]"," ", r)
    r = r.split()
    stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
    r = [w for w in r if not w in stopwords]
    r = " ".join(word for word in r)
    return r

# %%
# run tweets through clean_tweet function and display

cleaned = [clean_tweet(tw) for tw in tweet_list]
cleaned
# Out:
# ['nah college dropout skits are hilarious broke fi broke we aint got it',
#  'love this guy his presence support his team he along with amar doman are what nee',
#  'playoffs divisional final odds eastern final mtl alouettes 3 5 110 amp 138 tor argonauts 3 5 110 amp',
#  'coach o show with november 8th 2022 via via',
#  'offensive coordinator is first item roughriders offseason shopping list via',
#  'analysis division finals sunday are loaded with talent via via',
#  'pretty negative comments will be great football played outside great cfl feel real football',
#  'weekly predictor believing bombers via',
#  'thats eye watering li',
#  '3 storylines watch western final via',
#  'injuries return is never as good as before whoever signs this guy as s',
#  'was great moment eric epic canadiana moment',
#  'schedule events 109th grey cup championship week regina via',
#  'congratulations our cfl hall fans winner deborah way go stay tuned our next lucky winner',
#  'yeah im aware that re nfl still good model thats worth mentioning thats good re cfl',
#  '3850 tickets sale grey cup 3162 tickets sale wcf cannot confirm but i hope things pick up r',
#  'i ain t paid my rent nothing mike jones expects montreal alouettes complete grey cup run',
#  'now do cfl',
#  'is it just me or is that cfl spicy southwest salad getting spicier or am i getting old',
#  'impact linebackers headline hamilton tiger cats potential free agent list via',
#  'can you imagine shock when win grey cup against',
#  'hamilton tiger cats offensive lineman chris van zeyl plans return 14th cfl season v',
#  'november 7 simoni lawrence via',
#  'november 7 dane evans via',
#  'nfl bans public ownership teams only green bay is allowed continue with model that it ha',
#  'i love how many people have tried school you cfl nfl',
#  'really attend home home bs',
#  'blue bombers have been favourite win grey cup all season with theyre down final four',
#  'bonsoir just curious how many bars you checked out do you live qu bec city just curious',
#  'no shortage big names sundays western final between',
#  'this how i m feeling right now',
#  'i dont understand whats going at were two days removed pretty good',
#  'steven dunbar scores teams lone td loss',
#  'hamilton tiger cats offensive lineman chris van zeyl plans return 14th cfl season despite battling through',
#  'tim white leads team receiving',
#  'with permanent life insurance your coverage could help your family maintain their current lifestyle pay colle',
#  'dane evans gets benched loss',
#  'heres fran stuchburys last week around leagues',
#  'i hear ya brother but management life right outta us well still be there thoug',
#  'my guess is milanovich',
#  'nfl won t come here if torontonians won t support other football balti',
#  'this would be huge it reminds me when john candy amp gretzky bought toronto argonauts elevated cool',
#  'pure magic field those two connected',
#  'playoff level plays timbermart plays week',
#  'matthew shiltz splits work with evans',
#  'it is sad that big playoff game they can t fill stadium with reach about 3 million people',
#  'lots documented reasons why argos are where they are today',
#  'need big suitcase just all layers',
#  'well were waiting you buds meantime well support team w',
#  'im all pin badged up with my poppy cfl pins',
#  'william stanback 14 touches win',
#  'this morning their play it by ear segment cbc music played clips 1986 grey cup win as one t',
#  'just ask his teammates',
#  'cfl gym',
#  'congratulations who received his draft pool invitation would like thank you',
#  'jake wieneke catches touchdown win',
#  'bc lions 5 0 at winnipeg blue bombers sun 16 30et bonuses up 1500',
#  'montreal alouettes 3 5 at toronto argonauts sun 13 00et bonuses up 1500',
#  'met roger keeley fmr official today at acropolis sitting steps parthenon roger was',
#  'maybe 5 beer again now that won t ppl comin',
#  'great afternoon marking 10 years child friendly leeds its amazing see what cfl has done',
#  'absolutely i certainly dont undervalue amars friendship with jerry jones all his time spent',
#  'eugene lewis leads team receiving',
#  'how can i forget that',
#  'walter fletcher totals 102 scrimmage yards',
#  'if they were cfl probs',
#  '',
#  'lb simoni lawrence speaks with media following east semi final montreal simoni will be answering y',
#  '2022 cfl division semi finals recap ryan adam trey recap everything 2022 cfl division semi finals',
#  'read articles listen sport casters again hey i would love him be gre',
#  'how about heart being first item shopping list it something this team is truly lacking',
#  'buddy me',
#  'trevor harris efficient performance win',
#  'we have roof lol',
#  'it was awesome this cfl fan see too wish every stadium would get huge crowd every game enj',
#  'don t forget we also have 3 hot dogs but yo',
#  'nobody has called him best ever at anything yet tho more pointing out how inc',
#  'ol chris van zeyl speaks with media following east semi final montreal',
#  'i ain t paid my rent nothing mike jones expects montreal alouettes complete grey cup run',
#  'dt ted laurent speaks with media following east semi final montreal',
#  'not so much complaining as pointing out that today world especially sport jumps',
#  'theres still time them have wiggles come out one song before quote country allstar',
#  'cfl east montreal vs toronto tix sales i believe will be around 15 000 i always find it hard watch toronto m',
#  'fbcd had big news update coming fbc holding inc fbcd announces new brand ambassador cfl quarterback ben holm',
#  '3 storylines watch western final dust is slowly setting 2022 cfl season with just four te',
#  'qb dane evans speaks with media following east semi final montreal',
#  'too busy arguing with peyton',
#  'offensive coordinator is first item roughriders offseason shopping list end november is very b',
#  'that s great cfl we as fans have waited decades this kind playe',
#  'i just wish would have stayed with us man that guy was amazing watch',
#  'its awful how sports outside hockey nba mlb curling nfl some cfl get reported s',
#  'well that s pretty much whole team da',
#  'i m sure when went down this road month ago there were people muttering only',
#  'weekly predictor believing bombers division final matchups are set jamie nye has his picks ahead s',
#  'how many more sleeps until division finals',
#  'very disappointing stampeders mistakes costly west division semifinal loss lions',
#  'awesome sergio will you be playing it next year i hope so i ll have follow cfl more closely i',
#  'cfl playoff football is like 1000 times more exciting watch baseball is now played at slower pace than curling',
#  'soon as it hit 11 i m hitting up cfl',
#  'weekly predictor believing bombers']

# %% [markdown]
# ### Sentiment Analysis

# %%
# Define the sentiment objects using TextBlob

sentiment_objects = [TextBlob(tweet) for tweet in cleaned]

sentiment_objects[0].polarity, sentiment_objects[0:5]
# Out:
# (0.5,
#  [TextBlob("nah college dropout skits are hilarious broke fi broke we aint got it"),
#   TextBlob("love this guy his presence support his team he along with amar doman are what nee"),
#   TextBlob("playoffs divisional final odds eastern final mtl alouettes 3 5 110 amp 138 tor argonauts 3 5 110 amp"),
#   TextBlob("coach o show with november 8th 2022 via via"),
#   TextBlob("offensive coordinator is first item roughriders offseason shopping list via")])

# %%
# Create a list of polarity values and tweet text

sentiment_values = [[tweet.sentiment.polarity, str(tweet)] for tweet in sentiment_objects]

# Print the value of the 0th row.

sentiment_values[0]# Print all the sentiment values

sentiment_values[0:99]
# Out:
# [[0.5,
#   'nah college dropout skits are hilarious broke fi broke we aint got it'],
#  [0.5,
#   'love this guy his presence support his team he along with amar doman are what nee'],
#  [0.0,
#   'playoffs divisional final odds eastern final mtl alouettes 3 5 110 amp 138 tor argonauts 3 5 110 amp'],
#  [0.0, 'coach o show with november 8th 2022 via via'],
#  [0.25,
#   'offensive coordinator is first item roughriders offseason shopping list via'],
#  [0.0, 'analysis division finals sunday are loaded with talent via via'],
#  [0.2916666666666667,
#   'pretty negative comments will be great football played outside great cfl feel real football'],
#  [0.0, 'weekly predictor believing bombers via'],
#  [0.0, 'thats eye watering li'],
#  [0.0, '3 storylines watch western final via'],
#  [0.7,
#   'injuries return is never as good as before whoever signs this guy as s'],
#  [0.45, 'was great moment eric epic canadiana moment'],
#  [-0.05, 'schedule events 109th grey cup championship week regina via'],
#  [0.16666666666666666,
#   'congratulations our cfl hall fans winner deborah way go stay tuned our next lucky winner'],
#  [0.4875,
#   'yeah im aware that re nfl still good model thats worth mentioning thats good re cfl'],
#  [-0.05,
#   '3850 tickets sale grey cup 3162 tickets sale wcf cannot confirm but i hope things pick up r'],
#  [0.025,
#   'i ain t paid my rent nothing mike jones expects montreal alouettes complete grey cup run'],
#  [0.0, 'now do cfl'],
#  [0.1,
#   'is it just me or is that cfl spicy southwest salad getting spicier or am i getting old'],
#  [0.2,
#   'impact linebackers headline hamilton tiger cats potential free agent list via'],
#  [0.375, 'can you imagine shock when win grey cup against'],
#  [0.0,
#   'hamilton tiger cats offensive lineman chris van zeyl plans return 14th cfl season v'],
#  [0.0, 'november 7 simoni lawrence via'],
#  [0.0, 'november 7 dane evans via'],
#  [-0.06666666666666667,
#   'nfl bans public ownership teams only green bay is allowed continue with model that it ha'],
#  [0.5, 'i love how many people have tried school you cfl nfl'],
#  [0.2, 'really attend home home bs'],
#  [0.11888888888888889,
#   'blue bombers have been favourite win grey cup all season with theyre down final four'],
#  [0.1090909090909091,
#   'bonsoir just curious how many bars you checked out do you live qu bec city just curious'],
#  [0.0, 'no shortage big names sundays western final between'],
#  [0.2857142857142857, 'this how i m feeling right now'],
#  [0.475, 'i dont understand whats going at were two days removed pretty good'],
#  [0.0, 'steven dunbar scores teams lone td loss'],
#  [0.0,
#   'hamilton tiger cats offensive lineman chris van zeyl plans return 14th cfl season despite battling through'],
#  [0.0, 'tim white leads team receiving'],
#  [0.0,
#   'with permanent life insurance your coverage could help your family maintain their current lifestyle pay colle'],
#  [0.0, 'dane evans gets benched loss'],
#  [0.0, 'heres fran stuchburys last week around leagues'],
#  [0.2857142857142857,
#   'i hear ya brother but management life right outta us well still be there thoug'],
#  [0.0, 'my guess is milanovich'],
#  [-0.125,
#   'nfl won t come here if torontonians won t support other football balti'],
#  [0.375,
#   'this would be huge it reminds me when john candy amp gretzky bought toronto argonauts elevated cool'],
#  [0.35714285714285715, 'pure magic field those two connected'],
#  [0.0, 'playoff level plays timbermart plays week'],
#  [0.0, 'matthew shiltz splits work with evans'],
#  [-0.3,
#   'it is sad that big playoff game they can t fill stadium with reach about 3 million people'],
#  [0.0, 'lots documented reasons why argos are where they are today'],
#  [0.0, 'need big suitcase just all layers'],
#  [0.0, 'well were waiting you buds meantime well support team w'],
#  [0.0, 'im all pin badged up with my poppy cfl pins'],
#  [0.8, 'william stanback 14 touches win'],
#  [0.375,
#   'this morning their play it by ear segment cbc music played clips 1986 grey cup win as one t'],
#  [0.0, 'just ask his teammates'],
#  [0.0, 'cfl gym'],
#  [0.0,
#   'congratulations who received his draft pool invitation would like thank you'],
#  [0.8, 'jake wieneke catches touchdown win'],
#  [0.0, 'bc lions 5 0 at winnipeg blue bombers sun 16 30et bonuses up 1500'],
#  [0.0,
#   'montreal alouettes 3 5 at toronto argonauts sun 13 00et bonuses up 1500'],
#  [0.0,
#   'met roger keeley fmr official today at acropolis sitting steps parthenon roger was'],
#  [0.0, 'maybe 5 beer again now that won t ppl comin'],
#  [0.5916666666666667,
#   'great afternoon marking 10 years child friendly leeds its amazing see what cfl has done'],
#  [0.057142857142857134,
#   'absolutely i certainly dont undervalue amars friendship with jerry jones all his time spent'],
#  [0.0, 'eugene lewis leads team receiving'],
#  [0.0, 'how can i forget that'],
#  [0.0, 'walter fletcher totals 102 scrimmage yards'],
#  [0.0, 'if they were cfl probs'],
#  [0.0, ''],
#  [0.0,
#   'lb simoni lawrence speaks with media following east semi final montreal simoni will be answering y'],
#  [0.0,
#   '2022 cfl division semi finals recap ryan adam trey recap everything 2022 cfl division semi finals'],
#  [0.5, 'read articles listen sport casters again hey i would love him be gre'],
#  [0.25,
#   'how about heart being first item shopping list it something this team is truly lacking'],
#  [0.0, 'buddy me'],
#  [0.8, 'trevor harris efficient performance win'],
#  [0.8, 'we have roof lol'],
#  [0.3333333333333333,
#   'it was awesome this cfl fan see too wish every stadium would get huge crowd every game enj'],
#  [0.25, 'don t forget we also have 3 hot dogs but yo'],
#  [0.75,
#   'nobody has called him best ever at anything yet tho more pointing out how inc'],
#  [0.0,
#   'ol chris van zeyl speaks with media following east semi final montreal'],
#  [0.025,
#   'i ain t paid my rent nothing mike jones expects montreal alouettes complete grey cup run'],
#  [0.0, 'dt ted laurent speaks with media following east semi final montreal'],
#  [0.1,
#   'not so much complaining as pointing out that today world especially sport jumps'],
#  [0.0,
#   'theres still time them have wiggles come out one song before quote country allstar'],
#  [-0.2916666666666667,
#   'cfl east montreal vs toronto tix sales i believe will be around 15 000 i always find it hard watch toronto m'],
#  [0.06818181818181818,
#   'fbcd had big news update coming fbc holding inc fbcd announces new brand ambassador cfl quarterback ben holm'],
#  [-0.10000000000000002,
#   '3 storylines watch western final dust is slowly setting 2022 cfl season with just four te'],
#  [0.0, 'qb dane evans speaks with media following east semi final montreal'],
#  [0.1, 'too busy arguing with peyton'],
#  [0.225,
#   'offensive coordinator is first item roughriders offseason shopping list end november is very b'],
#  [0.7, 'that s great cfl we as fans have waited decades this kind playe'],
#  [0.6000000000000001,
#   'i just wish would have stayed with us man that guy was amazing watch'],
#  [-0.5,
#   'its awful how sports outside hockey nba mlb curling nfl some cfl get reported s'],
#  [0.225, 'well that s pretty much whole team da'],
#  [0.11481481481481481,
#   'i m sure when went down this road month ago there were people muttering only'],
#  [0.0,
#   'weekly predictor believing bombers division final matchups are set jamie nye has his picks ahead s'],
#  [0.5, 'how many more sleeps until division finals'],
#  [-0.78,
#   'very disappointing stampeders mistakes costly west division semifinal loss lions'],
#  [0.5,
#   'awesome sergio will you be playing it next year i hope so i ll have follow cfl more closely i'],
#  [0.4,
#   'cfl playoff football is like 1000 times more exciting watch baseball is now played at slower pace than curling'],
#  [0.0, 'soon as it hit 11 i m hitting up cfl']]

# %% [markdown]
# ### Create a DF of each tweet against its calculated polarity

# %%
sentiment_df = pd.DataFrame(sentiment_values, columns=["polarity", "tweet"])

sentiment_df
# Out:
#     polarity                                              tweet
# 0       0.50  nah college dropout skits are hilarious broke ...
# 1       0.50  love this guy his presence support his team he...
# 2       0.00  playoffs divisional final odds eastern final m...
# 3       0.00        coach o show with november 8th 2022 via via
# 4       0.25  offensive coordinator is first item roughrider...
# ..       ...                                                ...
# 95     -0.78  very disappointing stampeders mistakes costly ...
# 96      0.50  awesome sergio will you be playing it next yea...
# 97      0.40  cfl playoff football is like 1000 times more e...
# 98      0.00               soon as it hit 11 i m hitting up cfl
# 99      0.00                 weekly predictor believing bombers
#
# [100 rows x 2 columns]

# %%
# Save the polarity column as 'n'.

n=sentiment_df["polarity"]

# Convert this column into a series, 'm'. 

m=pd.Series(n)

m
# Out:
# 0     0.50
# 1     0.50
# 2     0.00
# 3     0.00
# 4     0.25
#       ...
# 95   -0.78
# 96    0.50
# 97    0.40
# 98    0.00
# 99    0.00
# Name: polarity, Length: 100, dtype: float64

# %% [markdown]
# We will now initialize three variables, ‘pos’, ‘neg’ and ‘neu’.
# We will use these variables to create a loop to classify the tweets as positive, negative, and neutral.

# %%
# Initialize variables, 'pos', 'neg', 'neu'.

pos=0
neg=0
neu=0

# Create a loop to classify the tweets as Positive, Negative, or Neutral.
# Count the number of each.

for items in m:
    if items>0:
        print("Positive")
        pos=pos+1
    elif items<0:
        print("Negative")
        neg=neg+1
    else:
        print("Neutral")
        neu=neu+1
        
print(pos,neg,neu)
# Out:
# Positive
# Positive
# Neutral
# Neutral
# Positive
# Neutral
# Positive
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Negative
# Positive
# Positive
# Negative
# Positive
# Neutral
# Positive
# Positive
# Positive
# Neutral
# Neutral
# Neutral
# Negative
# Positive
# Positive
# Positive
# Positive
# Neutral
# Positive
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Negative
# Positive
# Positive
# Neutral
# Neutral
# Negative
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Neutral
# Positive
# Positive
# Positive
# Positive
# Positive
# Neutral
# Positive
# Neutral
# Positive
# Neutral
# Negative
# Positive
# Negative
# Neutral
# Positive
# Positive
# Positive
# Positive
# Negative
# Positive
# Positive
# Neutral
# Positive
# Negative
# Positive
# Positive
# Neutral
# Neutral
# 45 9 46

# %% [markdown]
# ### Create pie chart to display results

# %%
pieLabels=["Positive","Negative","Neutral"]

populationShare=[pos,neg,neu]

figureObject, axesObject = plt.subplots()

axesObject.pie(populationShare,labels=pieLabels,autopct='%1.2f',startangle=90)

axesObject.axis('equal')

plt.show()

# %% [markdown]
# ### Identify certain terms that are most common in this topic with word cloud

# %%
# Create a Wordcloud from the tweets

all_words = ' '.join([text for text in cleaned])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
